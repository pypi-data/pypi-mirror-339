# %%
import pandas as pd
import glob

parquet_files = [p for p in glob.glob("~/data/flight/dataframes/*/*.parquet")]
[f for f in parquet_files]
df = pd.concat((pd.read_parquet(f) for f in parquet_files))
df
# Out:
#                                                                  files  \
# date
# 2020-04-02 14:47:36  b'Ka_Spirit_N686NK_NKS730_20200402145709Z_OFFL...
# 2020-04-02 14:47:46  b'Ka_Spirit_N686NK_NKS730_20200402145709Z_OFFL...
# 2020-04-02 14:47:56  b'Ka_Spirit_N686NK_NKS730_20200402145709Z_OFFL...
# 2020-04-02 14:48:06  b'Ka_Spirit_N686NK_NKS730_20200402145709Z_OFFL...
# 2020-04-02 14:48:16  b'Ka_Spirit_N686NK_NKS730_20200402145709Z_OFFL...
# ...                                                                ...
# 2020-04-06 18:17:39  b'Ka_Spirit_N660NK_NKS936_20200406151926Z_OFFL...
# 2020-04-06 18:17:49  b'Ka_Spirit_N660NK_NKS936_20200406151926Z_OFFL...
# 2020-04-06 18:17:59  b'Ka_Spirit_N660NK_NKS936_20200406151926Z_OFFL...
# 2020-04-06 18:18:09  b'Ka_Spirit_N660NK_NKS936_20200406151926Z_OFFL...
# 2020-04-06 18:18:19  b'Ka_Spirit_N660NK_NKS936_20200406151926Z_OFFL...
#
#                     flight_id  flight_serial  flying  aircraft cyclic_id  \
# date
# ...
